# %% [markdown]
# <a href="https://colab.research.google.com/github/armaanrathod/EDA-lab-3rd-sem-final/blob/14th/eda_lab_14th.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'StudentID': [1, 3, 5, 7, 9],
    'Score': [89, 39, 50, 97, 22]
})

dataFrame2 = pd.DataFrame({
    'StudentID': [2, 4, 6, 8, 10],
    'Score': [98, 93, 44, 77, 69]
})
print(df.mean())
print(df.max())
# Out:
# StudentID     5.0
# Score        59.4
# dtype: float64
# StudentID     9
# Score        97
# dtype: int64
