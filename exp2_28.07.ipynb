# %% [markdown]
# <a href="https://colab.research.google.com/github/armaanrathod/EDA-lab-3rd-sem-final/blob/main/exp2_28.07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
import io

uploaded = files.upload()

for fn in uploaded.keys():
  print(f'User uploaded file "{fn}"')
  try:
    restaurant_df_local = pd.read_csv(io.StringIO(uploaded[fn].decode('utf-8')))
    print(f"'{fn}' loaded successfully!")
    display(restaurant_df_local.head())
  except Exception as e:
    print(f"Error reading '{fn}': {e}")
# Out:
# Please select your 'restraunt.csv' file from your local system to upload:
#      <input type="file" id="files-351ebc53-69c7-4a3d-a991-27668d6c2dbe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-351ebc53-69c7-4a3d-a991-27668d6c2dbe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant_ID       0
# Name                0
# City                0
# State               0
# Country             0
# Zip_Code           74
# Latitude            0
# Longitude           0
# Alcohol_Service    87
# Smoking_Allowed     0
# Price               0
# Franchise           0
# Area                0
# Parking            65
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(226)

# %%
df.count()
# Out:
# Restaurant_ID      130
# Name               130
# City               130
# State              130
# Country            130
# Zip_Code            56
# Latitude           130
# Longitude          130
# Alcohol_Service     43
# Smoking_Allowed    130
# Price              130
# Franchise          130
# Area               130
# Parking             65
# dtype: int64

# %%
df.Zip_Code.dropna()
# Out:
# 4      62000.0
# 22     87018.0
# 29     62320.0
# 31     78280.0
# 33     78349.0
# 50     78433.0
# 61     62250.0
# 63     62290.0
# 67     62790.0
# 68     62170.0
# 74     62290.0
# 76     78250.0
# 80     78000.0
# 81     78399.0
# 82     78210.0
# 83     78210.0
# 84     78000.0
# 85     79300.0
# 86     74000.0
# 88     78269.0
# 90     78240.0
# 91     78000.0
# 92     78200.0
# 93     78310.0
# 94     78269.0
# 95     78214.0
# 96     78430.0
# 97     78000.0
# 98     78000.0
# 99     62460.0
# 100    78000.0
# 101    78270.0
# 102    78390.0
# 103    64000.0
# 104    78250.0
# 105    78310.0
# 106    78000.0
# 107    78000.0
# 108    78740.0
# 109    78250.0
# 110    78038.0
# 111    78399.0
# 112    78421.0
# 113    78396.0
# 114    78220.0
# 115    78000.0
# 116    78000.0
# 117    78269.0
# 118    78395.0
# 119    78000.0
# 120    78270.0
# 121    78000.0
# 122    78421.0
# 123    78000.0
# 124    78290.0
# 127    78000.0
# Name: Zip_Code, dtype: float64

# %%
filledDf = df.fillna(0)
filledDf
# Out:
#      Restaurant_ID                        Name             City  \
# 0           132560          Puesto de Gorditas  Ciudad Victoria
# 1           132561                  Cafe Ambar  Ciudad Victoria
# 2           132564                    Church's  Ciudad Victoria
# 3           132572                Cafe Chaires  San Luis Potosi
# 4           132583            McDonalds Centro       Cuernavaca
# ..             ...                         ...              ...
# 125         135088           Cafeteria Cenidet       Cuernavaca
# 126         135104                        Vips  Ciudad Victoria
# 127         135106  El Rincón De San Francisco  San Luis Potosi
# 128         135108                  Potzocalli  San Luis Potosi
# 129         135109                   Paniroles       Cuernavaca
#
#                State Country  Zip_Code   Latitude   Longitude Alcohol_Service  \
# 0         Tamaulipas  Mexico       0.0  23.752304  -99.166913               0
# ...
